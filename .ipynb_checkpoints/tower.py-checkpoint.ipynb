# %%
# Part 2: Theme Park Data Analysis
import numpy as np
import matplotlib.pyplot as plt
from scipy import integrate #This isn't working -- ImportError: no module named scipy
# %matplotlib inline

# Loads the data
vdata=np.loadtxt("droptower_vdata.txt", dtype=float)
print "time vs. velocity:", vdata

# Plot velocity over time
plt.plot(vdata[:,0], vdata[:,1])
plt.show()

# Plot position over time
x=integrate.cumtrapz(vdata[:,1], vdata[:,0], initial=0)
print "position=", x
plt.plot(vdata[:,0], x)
plt.show()

# Plot acceleration over time
a=np.diff(vdata[:,1])
print "acceleration=", a
plt.plot(vdata[1:,0],a)
plt.show()
# Out:
# time vs. velocity: [[  0.   15. ]
#  [  1.   17.6]
#  [  2.    7.8]
#  [  3.   -2. ]
#  [  4.  -11.8]
#  [  5.  -21.6]
#  [  6.  -19. ]
#  [  7.   -4. ]
#  [  8.   11. ]
#  [  9.   13.6]
#  [ 10.    3.8]]
# position= [  0.   16.3  29.   31.9  25.    8.3 -12.  -23.5 -20.   -7.7   1. ]
# acceleration= [  2.6  -9.8  -9.8  -9.8  -9.8   2.6  15.   15.    2.6  -9.8]
